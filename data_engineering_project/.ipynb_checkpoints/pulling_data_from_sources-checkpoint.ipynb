# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, count, expr

spark = SparkSession.builder.appName("VolcanicEruptions").getOrCreate()

spark.conf.set("spark.sql.repl.eagerEval.enabled", True)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['figure.figsize']=[15,11]
#plt.style.use('seaborn-bright')
plt.style.use('https://github.com/dhaitz/matplotlib-stylesheets/raw/master/pitayasmoothie-light.mplstyle')

# %%
historical_df = pd.read_excel(
    "./datasets/volcano-eruptions-all-historical-to-2020/volcanic_dataset.xls", header=1
)
historical_df.to_csv(
    "./datasets/volcano-eruptions-all-historical-to-2020/volcanic_dataset.csv"
)

# %%
dataset_path = (
    "./datasets/volcano-eruptions-all-historical-to-2020/volcanic_dataset.csv"
)


df = (
    spark.read.format("csv")
    .option("delimiter", ",")
    .option("header", "true")
    .option("inferSchema", "true")
    .load(dataset_path)
)


display(df)
# Out:
# +---+--------------+--------------------+---------------+------------------+--------------------+----+------------+-------------------+----------+----------------------+-----------+------------------+---------+---------------------+------------------------+-----------------+--------+--------------------+---------+----------------+-------+-------------------+--------+---------+
# |_c0|Volcano Number|        Volcano Name|Eruption Number| Eruption Category|    Area of Activity| VEI|VEI Modifier|Start Year Modifier|Start Year|Start Year Uncertainty|Start Month|Start Day Modifier|Start Day|Start Day Uncertainty|Evidence Method (dating)|End Year Modifier|End Year|End Year Uncertainty|End Month|End Day Modifier|End Day|End Day Uncertainty|Latitude|Longitude|
# +---+--------------+--------------------+---------------+------------------+--------------------+----+------------+-------------------+----------+----------------------+-----------+------------------+---------+---------------------+------------------------+-----------------+--------+--------------------+---------+----------------+-------+-------------------+--------+---------+
# |  0|        233020|Fournaise, Piton ...|          22343|Confirmed Eruption|                null|null|        null|               null|    2020.0|                  null|        2.0|              null|     10.0|                 null|    Historical Observ...|             null|  2020.0|                null|      2.0|            null|   16.0|               null| -21.244|   55.708|
# |  1|        345020|  Rincon de la Vieja|          22346|Confirmed Eruption|                null|null|        null|               null|    2020.0|                  null|        1.0|              null|     31.0|                 null|    Historical Observ...|             null|  2020.0|                null|      1.0|            null|   31.0|               null|   10.83|  -85.324|
# |  2|        353010|          Fernandina|          22347|Confirmed Eruption|                null|null|        null|               null|    2020.0|                  null|        1.0|              null|     12.0|                 null|    Historical Observ...|             null|  2020.0|                null|      1.0|            null|   12.0|               null|   -0.37|   -91.55|
# |  3|        273070|                Taal|          22344|Confirmed Eruption|                null|null|        null|               null|    2020.0|                  null|        1.0|              null|     12.0|                 null|    Historical Observ...|             null|  2020.0|                null|      1.0|            null|   22.0|               null|  14.002|  120.993|
# |  4|        282050|    Kuchinoerabujima|          22345|Confirmed Eruption|                null|null|        null|               null|    2020.0|                  null|        1.0|              null|     11.0|                 null|    Historical Observ...|                >|  2020.0|                null|      2.0|            null|   13.0|               null|  30.443|  130.217|
# |  5|        241040|        White Island|          22338|Confirmed Eruption|1978/90 Crater Co...| 2.0|        null|               null|    2019.0|                  null|       12.0|              null|      9.0|                 null|    Historical Observ...|             null|  2019.0|                null|     12.0|            null|    9.0|               null|  -37.52|   177.18|
# |  6|        311060|       Semisopochnoi|          22341|Confirmed Eruption|                null|null|        null|               null|    2019.0|                  null|       12.0|              null|      7.0|                 null|    Historical Observ...|                >|  2020.0|                null|      2.0|            null|   16.0|               null|   51.93|   179.58|
# |  7|        284096|        Nishinoshima|          22340|Confirmed Eruption|                null| 1.0|        null|               null|    2019.0|                  null|       12.0|              null|      5.0|                 null|    Historical Observ...|                >|  2020.0|                null|      2.0|            null|   15.0|               null|  27.247|  140.874|
# |  8|        311240|           Cleveland|          22342|Uncertain Eruption|                null|null|        null|               null|    2019.0|                  null|       11.0|              null|      7.0|                 null|    Historical Observ...|             null|  2019.0|                null|     12.0|               ?|    7.0|               null|  52.825| -169.944|
# |  9|        282060|               Kikai|          22339|Confirmed Eruption|                null|null|        null|               null|    2019.0|                  null|       11.0|              null|      2.0|                 null|    Historical Observ...|                >|  2020.0|                null|      2.0|            null|   11.0|               null|  30.793|  130.305|
# | 10|        300260|        Klyuchevskoy|          22335|Confirmed Eruption|                null|null|        null|               null|    2019.0|                  null|       10.0|              null|     24.0|                 null|    Historical Observ...|                >|  2020.0|                null|      2.0|            null|   19.0|               null|  56.056|  160.642|
# | 11|        243070|             Lateiki|          22334|Confirmed Eruption|                null| 1.0|        null|               null|    2019.0|                  null|       10.0|              null|     13.0|                 null|    Historical Observ...|             null|  2019.0|                null|     10.0|            null|   22.0|               null|  -19.18|  -174.87|
# | 12|        283110|           Asamayama|          22326|Confirmed Eruption|                null|null|        null|               null|    2019.0|                  null|        8.0|              null|      7.0|                 null|    Historical Observ...|             null|  2019.0|                null|      8.0|            null|   25.0|               null|  36.406|  138.523|
# | 13|        357090|             Copahue|          22336|Confirmed Eruption|                null|null|        null|               null|    2019.0|                  null|        8.0|              null|      2.0|                 null|    Historical Observ...|             null|  2019.0|                null|     11.0|               ?|   12.0|               null| -37.856|  -71.183|
# | 14|        263090|    Tangkuban Parahu|          22325|Confirmed Eruption|                null|null|        null|               null|    2019.0|                  null|        7.0|              null|     26.0|                 null|    Historical Observ...|             null|  2019.0|                null|      9.0|            null|   17.0|               null|   -6.77|    107.6|
# | 15|        311360|          Shishaldin|          22330|Confirmed Eruption|       Summit crater|null|        null|               null|    2019.0|                  null|        7.0|              null|     23.0|                 null|    Historical Observ...|             null|  2020.0|                null|      1.0|            null|   28.0|               null|  54.756|  -163.97|
# | 16|        351020|    Ruiz, Nevado del|          22329|Confirmed Eruption|                null|null|        null|               null|    2019.0|                  null|        7.0|              null|     23.0|                 null|    Historical Observ...|             null|  2019.0|                null|     10.0|            null|    4.0|               null|   4.892|  -75.324|
# | 17|        311060|       Semisopochnoi|          22328|Confirmed Eruption|                null|null|        null|               null|    2019.0|                  null|        7.0|              null|     16.0|                 null|    Historical Observ...|             null|  2019.0|                null|      8.0|            null|   24.0|               null|   51.93|   179.58|
# | 18|        252120|              Ulawun|          22319|Confirmed Eruption|                null|null|        null|               null|    2019.0|                  null|        6.0|              null|     26.0|                 null|    Historical Observ...|             null|  2019.0|                null|     10.0|            null|    5.0|               null|   -5.05|   151.33|
# | 19|        354020|              Ubinas|          22324|Confirmed Eruption|                null|null|        null|               null|    2019.0|                  null|        6.0|              null|     24.0|                 null|    Historical Observ...|             null|  2019.0|                null|     12.0|            null|   24.0|                7.0| -16.355|  -70.903|
# +---+--------------+--------------------+---------------+------------------+--------------------+----+------------+-------------------+----------+----------------------+-----------+------------------+---------+---------------------+------------------------+-----------------+--------+--------------------+---------+----------------+-------+-------------------+--------+---------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import lit
#eruptions = historical_df.groupby("Eruption Category").count()

eruptions = df.withColumn("Count",lit(1)).select("Eruption Category", "Count").groupBy("Eruption Category").agg(count("Count").alias("Total")).orderBy("Total")
display(eruptions)
# Out:
# +--------------------+-----+
# |   Eruption Category|Total|
# +--------------------+-----+
# |Discredited Eruption|  166|
# |  Uncertain Eruption| 1111|
# |  Confirmed Eruption| 9895|
# +--------------------+-----+

# %%
historical_df.plot(
    kind="scatter", x="Longitude", y="Latitude", cmap=plt.get_cmap("jet"), colorbar=True
)
# Out:
# /home/wiktor/.pyenv/versions/ml-notebooks/lib/python3.9/site-packages/pandas/plotting/_matplotlib/tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# <AxesSubplot:xlabel='Longitude', ylabel='Latitude'>
