# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import count, expr, col

import pandas as pd
import requests


spark = SparkSession.builder.appName("VolcanicEruptions").getOrCreate()

spark.conf.set("spark.sql.repl.eagerEval.enabled", True)

# %%
historical_df = pd.read_excel("./datasets/volcano-eruptions-all-historical-to-2020/volcanic_dataset.xls", header=1)
historical_df.to_csv("./datasets/volcano-eruptions-all-historical-to-2020/volcanic_dataset.csv")
display(historical_df)
# Out:
#        Volcano Number            Volcano Name  Eruption Number  \
# 0              233020  Fournaise, Piton de la            22343
# 1              345020      Rincon de la Vieja            22346
# 2              353010              Fernandina            22347
# 3              273070                    Taal            22344
# 4              282050        Kuchinoerabujima            22345
# ...               ...                     ...              ...
# 11167          327812                Red Hill            22193
# 11168          213020             Nemrut Dagi            13908
# 11169          324020     Craters of the Moon            21101
# 11170          222161            Igwisi Hills            22141
# 11171          390090                Saunders            21099
#
#         Eruption Category Area of Activity  VEI VEI Modifier  \
# 0      Confirmed Eruption              NaN  NaN          NaN
# 1      Confirmed Eruption              NaN  NaN          NaN
# ...

# %%
dataset_path = "./datasets/volcano-eruptions-all-historical-to-2020/volcanic_dataset.csv"


df = spark.read.format("csv").option("delimiter", ",").option("header", "true").option("inferSchema", "true").load(dataset_path)
    

display(df)
# Out:
#   File "<ipython-input-35-76da30fcf6a7>", line 9
#     df = spark.read.format("csv")/
#                                   ^
# SyntaxError: invalid syntax

# %%
df.where(col("Start Year Modifier").isNotNull())
# Out:
# +----+--------------+--------------------+---------------+------------------+--------------------+----+------------+-------------------+----------+----------------------+-----------+------------------+---------+---------------------+------------------------+-----------------+--------+--------------------+---------+----------------+-------+-------------------+--------+---------+
# | _c0|Volcano Number|        Volcano Name|Eruption Number| Eruption Category|    Area of Activity| VEI|VEI Modifier|Start Year Modifier|Start Year|Start Year Uncertainty|Start Month|Start Day Modifier|Start Day|Start Day Uncertainty|Evidence Method (dating)|End Year Modifier|End Year|End Year Uncertainty|End Month|End Day Modifier|End Day|End Day Uncertainty|Latitude|Longitude|
# ...
