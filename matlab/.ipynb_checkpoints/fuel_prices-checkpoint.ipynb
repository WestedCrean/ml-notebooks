# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
plt.rcParams["figure.figsize"] = (20,15)
DATE_START = '2007-01-01' # datetime.date(2007, 1, 1)
DATE_STOP =  '2017-01-01' # datetime.date(2017, 1, 1)

usdpln = pd.read_csv("usdpln.csv")
usdpln['Date'] =  pd.to_datetime(usdpln['Date'])
usdpln.set_index('Date')
oil_prices_us = pd.read_csv('BrentOilPrices.csv')
oil_prices_us['Date'] =  pd.to_datetime(oil_prices_us['Date'])
oil_prices_us = oil_prices_us.loc[ (DATE_START <= oil_prices_us['Date']) & (oil_prices_us['Date'] <= DATE_STOP) ]
oil_prices_us.sort_values(by=['Date'], ascending=True, inplace=True)
oil_prices_us.set_index('Date')
display(oil_prices_us)
# Out:
#            Date  Price
# 4996 2007-01-02  58.49
# 4997 2007-01-03  56.63
# 4998 2007-01-04  54.58
# 4999 2007-01-05  52.82
# 5000 2007-01-08  52.82
# ...         ...    ...
# 7511 2016-12-22  54.04
# 7512 2016-12-23  53.93
# 7513 2016-12-28  54.95
# 7514 2016-12-29  54.97
# 7515 2016-12-30  54.96
#
# [2520 rows x 2 columns]

# %%
oil_prices_pl = pd.read_excel('ceny_benzyny_95.xlsx')
oil_prices_pl.rename(columns={'Data zmiany': 'Date'}, inplace=True)
oil_prices_pl['Date'] =  pd.to_datetime(oil_prices_pl['Date'])
oil_prices_pl = oil_prices_pl.loc[ (DATE_START <= oil_prices_pl['Date']) & (oil_prices_pl['Date'] <= DATE_STOP) ]
oil_prices_pl.set_index('Date')
oil_prices_pl.sort_values(by=['Date'], ascending=True, inplace=True)
display(oil_prices_pl)
# Out:
#            Date  Cena  Akcyza  Opłata paliwowa
# 3596 2007-01-01  2982    1565            81.99
# 3595 2007-01-03  2982    1565            81.99
# 3594 2007-01-04  2982    1565            81.99
# 3593 2007-01-05  2957    1565            81.99
# 3592 2007-01-06  2953    1565            81.99
# ...         ...   ...     ...              ...
# 1076 2016-12-23  3710    1540           129.41
# 1075 2016-12-24  3701    1540           129.41
# 1074 2016-12-29  3743    1540           129.41
# 1073 2016-12-30  3757    1540           129.41
# 1072 2016-12-31  3733    1540           129.41
#
# [2525 rows x 4 columns]

# %%
usdpln = usdpln[['Date','Open']]

# %%
df = oil_prices_us.merge(oil_prices_pl, on="Date")
df = df.merge(usdpln, on="Date")
df.rename(columns={'Date': 'Data', 'Price': 'Cena US', 'Cena': 'Cena PL', 'Open': 'Kurs USDPLN'}, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1919 entries, 0 to 1918
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Data             1919 non-null   datetime64[ns]
#  1   Cena US          1919 non-null   float64
#  2   Cena PL          1919 non-null   int64
#  3   Akcyza           1919 non-null   int64
#  4   Opłata paliwowa  1919 non-null   float64
#  5   Kurs USDPLN      1919 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(2)
# memory usage: 104.9 KB
#            Data  Cena US  Cena PL  Akcyza  Opłata paliwowa  Kurs USDPLN
# 0    2007-01-03    56.63     2982    1565            81.99      2.88300
# 1    2007-01-04    54.58     2982    1565            81.99      2.91270
# 2    2007-01-05    52.82     2957    1565            81.99      2.97330
# 3    2007-01-09    52.38     2938    1565            81.99      2.95500
# 4    2007-01-10    52.11     2928    1565            81.99      2.99470
# ...         ...      ...      ...     ...              ...          ...
# 1914 2016-12-21    53.01     3713    1540           129.41      4.24340
# 1915 2016-12-22    54.04     3716    1540           129.41      4.23009
# 1916 2016-12-23    53.93     3710    1540           129.41      4.23559
# 1917 2016-12-29    54.97     3743    1540           129.41      4.22964
# 1918 2016-12-30    54.96     3757    1540           129.41      4.19980
#
# [1919 rows x 6 columns]

# %%
plt.rcParams["figure.figsize"] = (20,11)

fig, ax = plt.subplots()

x = df['Data']

y1 = df['Cena US'] * df['Kurs USDPLN']
y2 = df['Cena PL']

line1, = ax.plot(x, y1)
line2, = ax.plot(x, y2)

line1.set_label('Cena US w przeliczeniu')
line2.set_label('Cena PL')

ax.set_xlabel('Czas')
ax.legend()
plt.show()
display(df)
# Out:
#            Data  Cena US  Cena PL  Akcyza  Opłata paliwowa  Kurs USDPLN
# 0    2007-01-03    56.63     2982    1565            81.99      2.88300
# 1    2007-01-04    54.58     2982    1565            81.99      2.91270
# 2    2007-01-05    52.82     2957    1565            81.99      2.97330
# 3    2007-01-09    52.38     2938    1565            81.99      2.95500
# 4    2007-01-10    52.11     2928    1565            81.99      2.99470
# ...         ...      ...      ...     ...              ...          ...
# 1914 2016-12-21    53.01     3713    1540           129.41      4.24340
# 1915 2016-12-22    54.04     3716    1540           129.41      4.23009
# 1916 2016-12-23    53.93     3710    1540           129.41      4.23559
# 1917 2016-12-29    54.97     3743    1540           129.41      4.22964
# 1918 2016-12-30    54.96     3757    1540           129.41      4.19980
#
# [1919 rows x 6 columns]

# %%
# resample from daily to weekly

logic = {'Cena US'  : 'mean',
         'Cena US'  : 'mean',
         'Akcyza'   : 'mean',
         'Opłata paliwowa' : 'mean',
         'Kurs USDPLN': 'mean'}

offset = pd.offsets.timedelta(days=-6)

f = pd.read_clipboard(parse_dates=['Date'], index_col=['Date'])
f.resample('W', loffset=offset).apply(logic)

# %%
from pandas.plotting import scatter_matrix

attributes = ["Cena US", "Cena PL", "Kurs USDPLN"]
scatter_matrix(df[attributes])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024D08090CA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024D080C71F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024D080EF640>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024D0811BA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024D0814AEE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024D081832B0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024D081833A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024D07A702B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024D0799FAF0>]],
#       dtype=object)

# %%
df.mode(numeric_only=True)
# Out:
#    Cena US  Cena PL  Akcyza  Opłata paliwowa  Kurs USDPLN
# 0   108.98   4142.0  1565.0           129.41       2.7268
# 1      NaN      NaN     NaN              NaN       2.8451
# 2      NaN      NaN     NaN              NaN       3.0297
# 3      NaN      NaN     NaN              NaN       3.0321
# 4      NaN      NaN     NaN              NaN       3.0525
# 5      NaN      NaN     NaN              NaN       3.1036
# 6      NaN      NaN     NaN              NaN       3.1056
# 7      NaN      NaN     NaN              NaN       3.1566
# 8      NaN      NaN     NaN              NaN       3.2889
# 9      NaN      NaN     NaN              NaN       3.7197
